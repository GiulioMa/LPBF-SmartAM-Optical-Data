# %%
import pickle

# Path to data
base_path = './Data/Neuchatel_316L'

# Path to the segmented data
pickle_file_path = base_path + '/segmented_data_dict.pkl'  

# Load the dictionary from the pickle file
with open(pickle_file_path, 'rb') as file:
    segmented_data_dict = pickle.load(file)

print('Loaded segmented_data_dict from file.')
# Out:
# Loaded segmented_data_dict from file.

# %%
def print_segmented_data_summary(segmented_data_dict):
    print("Summary of Segmented Data:")
    for key, tensor in segmented_data_dict.items():
        power, speed, cube_number = key
        print(f"Cube {cube_number}, Power: {power}W, Speed: {speed}mm/s - Tensor Size: {tensor.shape}")

# Call the summary function
print_segmented_data_summary(segmented_data_dict)
# Out:
# Summary of Segmented Data:
# Cube 1, Power: 90W, Speed: 1050mm/s - Tensor Size: (10, 2, 2213)
# Cube 1, Power: 90W, Speed: 800mm/s - Tensor Size: (10, 2, 2795)
# Cube 1, Power: 120W, Speed: 1800mm/s - Tensor Size: (10, 2, 1407)
# Cube 1, Power: 120W, Speed: 1300mm/s - Tensor Size: (10, 2, 1835)
# Cube 1, Power: 120W, Speed: 550mm/s - Tensor Size: (10, 2, 3636)
# Cube 1, Power: 120W, Speed: 800mm/s - Tensor Size: (10, 2, 2498)
# Cube 1, Power: 90W, Speed: 1300mm/s - Tensor Size: (10, 2, 1535)
# Cube 1, Power: 105W, Speed: 1050mm/s - Tensor Size: (10, 2, 1902)
# Cube 1, Power: 90W, Speed: 1550mm/s - Tensor Size: (10, 2, 1286)
# Cube 1, Power: 105W, Speed: 1800mm/s - Tensor Size: (10, 2, 1106)
# Cube 2, Power: 105W, Speed: 800mm/s - Tensor Size: (11, 2, 2469)
# Cube 2, Power: 120W, Speed: 300mm/s - Tensor Size: (10, 2, 6671)
# Cube 2, Power: 105W, Speed: 1300mm/s - Tensor Size: (10, 2, 1535)
# Cube 2, Power: 120W, Speed: 1050mm/s - Tensor Size: (10, 2, 1902)
# Cube 2, Power: 105W, Speed: 300mm/s - Tensor Size: (10, 2, 6666)
# Cube 2, Power: 90W, Speed: 550mm/s - Tensor Size: (10, 2, 3634)
# Cube 2, Power: 105W, Speed: 1550mm/s - Tensor Size: (10, 2, 1288)
# Cube 2, Power: 120W, Speed: 1550mm/s - Tensor Size: (10, 2, 1289)
# Cube 2, Power: 90W, Speed: 300mm/s - Tensor Size: (10, 2, 6663)
# Cube 2, Power: 105W, Speed: 550mm/s - Tensor Size: (11, 2, 3636)
# Cube 3, Power: 90W, Speed: 1550mm/s - Tensor Size: (10, 2, 1260)
# Cube 3, Power: 120W, Speed: 1300mm/s - Tensor Size: (10, 2, 1536)
# Cube 3, Power: 90W, Speed: 1050mm/s - Tensor Size: (10, 2, 1901)
# Cube 3, Power: 120W, Speed: 300mm/s - Tensor Size: (10, 2, 6673)
# Cube 3, Power: 120W, Speed: 550mm/s - Tensor Size: (10, 2, 3635)
# Cube 3, Power: 120W, Speed: 1050mm/s - Tensor Size: (10, 2, 1903)
# Cube 3, Power: 105W, Speed: 1800mm/s - Tensor Size: (10, 2, 1109)
# Cube 3, Power: 105W, Speed: 300mm/s - Tensor Size: (10, 2, 6665)
# Cube 3, Power: 90W, Speed: 800mm/s - Tensor Size: (10, 2, 2497)
# Cube 3, Power: 90W, Speed: 1300mm/s - Tensor Size: (10, 2, 1535)
# Cube 4, Power: 105W, Speed: 800mm/s - Tensor Size: (10, 2, 2467)
# Cube 4, Power: 120W, Speed: 800mm/s - Tensor Size: (10, 2, 2498)
# Cube 4, Power: 105W, Speed: 1050mm/s - Tensor Size: (10, 2, 1902)
# Cube 4, Power: 105W, Speed: 1550mm/s - Tensor Size: (10, 2, 1287)
# Cube 4, Power: 105W, Speed: 550mm/s - Tensor Size: (10, 2, 3639)
# Cube 4, Power: 90W, Speed: 300mm/s - Tensor Size: (10, 2, 6664)
# Cube 4, Power: 120W, Speed: 1800mm/s - Tensor Size: (10, 2, 1110)
# Cube 4, Power: 105W, Speed: 1300mm/s - Tensor Size: (10, 2, 1536)
# Cube 4, Power: 120W, Speed: 1550mm/s - Tensor Size: (10, 2, 1288)
# Cube 4, Power: 90W, Speed: 550mm/s - Tensor Size: (10, 2, 3633)
# Cube 5, Power: 90W, Speed: 1300mm/s - Tensor Size: (10, 2, 1505)
# Cube 5, Power: 105W, Speed: 1550mm/s - Tensor Size: (10, 2, 1288)
# Cube 5, Power: 120W, Speed: 1800mm/s - Tensor Size: (10, 2, 1108)
# Cube 5, Power: 120W, Speed: 300mm/s - Tensor Size: (10, 2, 6674)
# Cube 5, Power: 90W, Speed: 1550mm/s - Tensor Size: (11, 2, 965)
# Cube 5, Power: 120W, Speed: 1550mm/s - Tensor Size: (11, 2, 1289)
# Cube 5, Power: 105W, Speed: 1050mm/s - Tensor Size: (10, 2, 1902)
# Cube 5, Power: 105W, Speed: 800mm/s - Tensor Size: (10, 2, 2498)
# Cube 5, Power: 105W, Speed: 1300mm/s - Tensor Size: (10, 2, 1536)
# Cube 5, Power: 90W, Speed: 800mm/s - Tensor Size: (10, 2, 2495)
# Cube 6, Power: 120W, Speed: 1300mm/s - Tensor Size: (10, 2, 1507)
# Cube 6, Power: 120W, Speed: 550mm/s - Tensor Size: (10, 2, 3641)
# Cube 6, Power: 105W, Speed: 300mm/s - Tensor Size: (10, 2, 6674)
# Cube 6, Power: 120W, Speed: 800mm/s - Tensor Size: (10, 2, 2497)
# Cube 6, Power: 90W, Speed: 1050mm/s - Tensor Size: (10, 2, 1899)
# Cube 6, Power: 105W, Speed: 550mm/s - Tensor Size: (10, 2, 3639)
# Cube 6, Power: 105W, Speed: 1800mm/s - Tensor Size: (10, 2, 1109)
# Cube 6, Power: 90W, Speed: 300mm/s - Tensor Size: (10, 2, 6666)
# Cube 6, Power: 90W, Speed: 550mm/s - Tensor Size: (10, 2, 3633)
# Cube 6, Power: 120W, Speed: 1050mm/s - Tensor Size: (10, 2, 1903)
# Cube 7, Power: 105W, Speed: 300.0mm/s - Tensor Size: (10, 2, 6674)
# Cube 7, Power: 105W, Speed: 1642.105263157895mm/s - Tensor Size: (10, 2, 1215)
# Cube 7, Power: 105W, Speed: 1484.210526315789mm/s - Tensor Size: (10, 2, 1344)
# Cube 7, Power: 105W, Speed: 378.9473684210526mm/s - Tensor Size: (10, 2, 5284)
# Cube 7, Power: 105W, Speed: 931.578947368421mm/s - Tensor Size: (10, 2, 2143)
# Cube 7, Power: 105W, Speed: 694.7368421052631mm/s - Tensor Size: (10, 2, 2876)
# Cube 7, Power: 105W, Speed: 1168.421052631579mm/s - Tensor Size: (10, 2, 1711)
# Cube 7, Power: 105W, Speed: 536.8421052631579mm/s - Tensor Size: (10, 2, 3727)
# Cube 7, Power: 105W, Speed: 1721.052631578947mm/s - Tensor Size: (10, 2, 1161)
# Cube 7, Power: 105W, Speed: 1563.157894736842mm/s - Tensor Size: (10, 2, 1278)
# Cube 8, Power: 105W, Speed: 1326.315789473684mm/s - Tensor Size: (11, 2, 979)
# Cube 8, Power: 105W, Speed: 457.8947368421053mm/s - Tensor Size: (11, 2, 4369)
# Cube 8, Power: 105W, Speed: 1010.526315789474mm/s - Tensor Size: (10, 2, 1977)
# Cube 8, Power: 105W, Speed: 1800.0mm/s - Tensor Size: (11, 2, 730)
# Cube 8, Power: 105W, Speed: 615.7894736842105mm/s - Tensor Size: (11, 2, 2924)
# Cube 8, Power: 105W, Speed: 1247.368421052632mm/s - Tensor Size: (10, 2, 1603)
# Cube 8, Power: 105W, Speed: 852.6315789473684mm/s - Tensor Size: (10, 2, 2345)
# Cube 8, Power: 105W, Speed: 1089.473684210526mm/s - Tensor Size: (10, 2, 1836)
# Cube 8, Power: 105W, Speed: 1405.263157894737mm/s - Tensor Size: (11, 2, 922)
# Cube 8, Power: 105W, Speed: 773.6842105263158mm/s - Tensor Size: (11, 2, 1679)
# Cube 9, Power: 90W, Speed: 1050mm/s - Tensor Size: (10, 2, 1890)
# Cube 9, Power: 90W, Speed: 800mm/s - Tensor Size: (10, 2, 2496)
# Cube 9, Power: 120W, Speed: 1800mm/s - Tensor Size: (10, 2, 1110)
# Cube 9, Power: 120W, Speed: 1300mm/s - Tensor Size: (10, 2, 1537)
# Cube 9, Power: 120W, Speed: 550mm/s - Tensor Size: (10, 2, 3639)
# Cube 9, Power: 120W, Speed: 800mm/s - Tensor Size: (10, 2, 2500)
# Cube 9, Power: 90W, Speed: 1300mm/s - Tensor Size: (10, 2, 1537)
# Cube 9, Power: 105W, Speed: 1050mm/s - Tensor Size: (10, 2, 1906)
# Cube 9, Power: 90W, Speed: 1550mm/s - Tensor Size: (10, 2, 1285)
# Cube 9, Power: 105W, Speed: 1800mm/s - Tensor Size: (10, 2, 1108)

# %%
import numpy as np

# New dictionary to hold the reduced tensors
reduced_data_dict = {}

for key, tensor in segmented_data_dict.items():
    # Step 1: Reduce the tensor to (1, 2, M) using the median across the first axis
    median_tensor = np.median(tensor[2:,:,int(tensor.shape[-1]*0.1):int(tensor.shape[-1]*0.9)], axis=0, keepdims=True)
    
    # Step 2: Calculate the median and std along the last axis for the reduced tensor
    median_of_median = np.median(median_tensor, axis=-1, keepdims=True)
    std_dev = np.std(median_tensor, axis=-1, keepdims=True)
    
    # Combine the median of median and std_dev into a single tensor (1, 2, 2)
    combined_tensor = np.concatenate((median_of_median, std_dev), axis=-1)
    
    # Store in the new dictionary
    reduced_data_dict[key] = combined_tensor

# %%
print_segmented_data_summary(reduced_data_dict)
# Out:
# Summary of Segmented Data:
# Cube 1, Power: 90W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 90W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 120W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 120W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 120W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 120W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 90W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 105W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 90W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 1, Power: 105W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 105W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 120W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 105W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 120W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 105W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 90W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 105W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 120W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 90W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 2, Power: 105W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 90W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 120W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 90W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 120W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 120W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 120W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 105W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 105W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 90W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 3, Power: 90W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 105W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 120W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 105W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 105W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 105W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 90W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 120W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 105W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 120W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 4, Power: 90W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 90W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 105W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 120W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 120W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 90W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 120W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 105W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 105W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 105W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 5, Power: 90W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 120W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 120W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 105W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 120W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 90W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 105W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 105W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 90W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 90W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 6, Power: 120W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 300.0mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 1642.105263157895mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 1484.210526315789mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 378.9473684210526mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 931.578947368421mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 694.7368421052631mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 1168.421052631579mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 536.8421052631579mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 1721.052631578947mm/s - Tensor Size: (1, 2, 2)
# Cube 7, Power: 105W, Speed: 1563.157894736842mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 1326.315789473684mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 457.8947368421053mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 1010.526315789474mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 1800.0mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 615.7894736842105mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 1247.368421052632mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 852.6315789473684mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 1089.473684210526mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 1405.263157894737mm/s - Tensor Size: (1, 2, 2)
# Cube 8, Power: 105W, Speed: 773.6842105263158mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 90W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 90W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 120W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 120W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 120W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 120W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 90W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 105W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 90W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Cube 9, Power: 105W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)

# %%
def combine_cube_data(cubes_to_analyze, data_dict):
    combined_data_dict = {}
    
    for key, data in data_dict.items():
        power, speed, cube_number = key
        # Check if the current entry is from one of the cubes we're interested in
        if cube_number in cubes_to_analyze:
            # Use (power, speed) as the new key
            new_key = (power, speed)
            
            combined_data_dict[new_key] = data
            
    return combined_data_dict

# %%
cubes_data = combine_cube_data(cubes_to_analyze=[5,6], data_dict=reduced_data_dict)
cubes_data
# Out:
# {(90,
#   1300): array([[[0.57540893, 0.10317136],
#          [0.42751315, 0.06531808]]]),
#  (105,
#   1550): array([[[0.6980133 , 0.09156386],
#          [0.44624325, 0.0733064 ]]]),
#  (120,
#   1800): array([[[0.8293152 , 0.08739722],
#          [0.44113155, 0.06770266]]]),
#  (120,
#   300): array([[[0.255661  , 0.03783167],
#          [0.39733885, 0.02589399]]]),
#  (90,
#   1550): array([[[0.8119965 , 0.13511607],
#          [0.39711   , 0.06887893]]]),
#  (120,
#   1550): array([[[1.057129  , 0.11330072],
#          [0.4283142 , 0.09308332]]]),
#  (105,
#   1050): array([[[0.91339115, 0.15489833],
#          [0.4192352 , 0.07970625]]]),
#  (105,
#   800): array([[[0.59570315, 0.12318379],
#          [0.4310608 , 0.05735896]]]),
#  (105,
#   1300): array([[[0.80062865, 0.15089118],
#          [0.5612946 , 0.16770331]]]),
#  (90,
#   800): array([[[0.3181076 , 0.07148137],
#          [0.43083193, 0.06997962]]]),
#  (120,
#   1300): array([[[0.6456375 , 0.09531826],
#          [0.65872193, 0.13839957]]]),
#  (120,
#   550): array([[[0.2577591 , 0.03621007],
#          [0.45074465, 0.04305758]]]),
#  (105,
#   300): array([[[0.2805328 , 0.04505545],
#          [0.3833771 , 0.03130943]]]),
#  (120,
#   800): array([[[0.59547423, 0.09028521],
#          [0.55034635, 0.07328165]]]),
#  (90,
#   1050): array([[[0.7382965 , 0.09529696],
#          [0.4331207 , 0.06097773]]]),
#  (105,
#   550): array([[[0.35556793, 0.04149388],
#          [0.3968048 , 0.03045454]]]),
#  (105,
#   1800): array([[[0.87360385, 0.0935305 ],
#          [0.52200318, 0.10455934]]]),
#  (90,
#   300): array([[[0.33370975, 0.06573791],
#          [0.34805295, 0.02123872]]]),
#  (90,
#   550): array([[[0.23288728, 0.03383517],
#          [0.35484315, 0.02447594]]]),
#  (120,
#   1050): array([[[0.43121338, 0.08646917],
#          [0.67466735, 0.11480954]]])}

# %%
def print_data_summary(segmented_data_dict):
    print("Summary of Segmented Data:")
    for key, tensor in segmented_data_dict.items():
        power, speed = key
        print(f"Power: {power}W, Speed: {speed}mm/s - Tensor Size: {tensor.shape}")

# %%
print_data_summary(cubes_data)
# Out:
# Summary of Segmented Data:
# Power: 90W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Power: 90W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 1550mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Power: 90W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 1300mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 800mm/s - Tensor Size: (1, 2, 2)
# Power: 90W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Power: 105W, Speed: 1800mm/s - Tensor Size: (1, 2, 2)
# Power: 90W, Speed: 300mm/s - Tensor Size: (1, 2, 2)
# Power: 90W, Speed: 550mm/s - Tensor Size: (1, 2, 2)
# Power: 120W, Speed: 1050mm/s - Tensor Size: (1, 2, 2)

# %%
import matplotlib.pyplot as plt

def plot_power_speed_data(combined_data_dict):
    # Extract unique power values
    unique_powers = sorted(set(power for (power, _) in combined_data_dict.keys()))
    
    # For each unique power, find all speeds and process data
    for power in unique_powers:
        # Filter keys by power and sort speeds
        speeds = sorted(speed for (p, speed) in combined_data_dict.keys() if p == power)
        
        # Data for plotting
        medians_channel_0 = []
        medians_channel_1 = []
        stds_channel_0 = []
        stds_channel_1 = []
        for speed in speeds:
            data = combined_data_dict[(power, speed)]
            # Data shape is (1, 2, 2), where last dim is [median, std]
            medians_channel_0.append(data[0, 0, 0])
            stds_channel_0.append(data[0, 0, 1])
            medians_channel_1.append(data[0, 1, 0])
            stds_channel_1.append(data[0, 1, 1])
        
        # Plotting
        fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=False)
        fig.suptitle(f'Optical Data for Power = {power}W')
        
        axs[0].errorbar(speeds, medians_channel_0, yerr=stds_channel_0, fmt='-o', label='Channel 0: Emission')
        axs[1].errorbar(speeds, medians_channel_1, yerr=stds_channel_1, fmt='-o', color='r', label='Channel 1: Reflection')
        
        axs[0].set_xlabel('Speed (mm/s)')
        axs[0].set_ylabel('Median with STD')
        axs[0].legend()
        axs[1].set_xlabel('Speed (mm/s)')
        axs[1].legend()

        plt.show()

# %%
plot_power_speed_data(cubes_data)

# %%
import matplotlib.pyplot as plt

def plot_power_speed_data(combined_data_dict):
    # Extract unique power values
    unique_powers = sorted(set(power for (power, _) in combined_data_dict.keys()))
    
    # For each unique power, find all speeds and process data
    for power in unique_powers:
        # Filter keys by power and sort speeds
        speeds = sorted(speed for (p, speed) in combined_data_dict.keys() if p == power)
        
        # Data for plotting
        medians_channel_0 = []
        medians_channel_1 = []
        stds_channel_0 = []
        stds_channel_1 = []
        for speed in speeds:
            data = combined_data_dict[(power, speed)]
            # Data shape is (1, 2, 2), where last dim is [median, std]
            medians_channel_0.append(data[0, 0, 0])
            stds_channel_0.append(data[0, 0, 1])
            medians_channel_1.append(data[0, 1, 0])
            stds_channel_1.append(data[0, 1, 1])
        
        # Plotting with two y-axes
        fig, ax1 = plt.subplots(figsize=(12, 6))
        fig.suptitle(f'Optical Data for Power = {power}W')
        
        color1 = 'tab:blue'
        ax1.set_xlabel('Speed (mm/s)')
        ax1.set_ylabel('Channel 0: Emission', color=color1)
        ax1.errorbar(speeds, medians_channel_0, yerr=stds_channel_0, fmt='-o', color=color1, label='Channel 0: Emission')
        ax1.tick_params(axis='y', labelcolor=color1)
        
        # Instantiate a second y-axis
        ax2 = ax1.twinx()
        color2 = 'tab:red'
        ax2.set_ylabel('Channel 1: Reflection', color=color2)
        ax2.errorbar(speeds, medians_channel_1, yerr=stds_channel_1, fmt='-o', color=color2, label='Channel 1: Reflection')
        ax2.tick_params(axis='y', labelcolor=color2)
        
        # Optional: Add a legend or customize further
        fig.tight_layout()  # For layout adjustment

        plt.show()

# %%
plot_power_speed_data(cubes_data)
